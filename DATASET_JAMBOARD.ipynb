# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliethAE/TalentoTech/blob/main/DATASET_JAMBOARD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas
data = {
'ID' : ['1' , '2' , '3' , '4' , '5', '3' , '5'],
'WEIGHT' : ['144.5' , '167.2' , '124.1' , '144.5', '133.2', '124.1', '129.2'],
'HEIGHT' : ['5.9','5.4', '5.2', '5.9', '5.7', '5.2', '5.3'],
'AGE': [33,45,23,33,54,23,42],
'GENDER':['M', 'M', 'F', 'M', 'F', 'F', 'M']
}
df_persona = pd.DataFrame(data)

# %%
df_persona.head()
# Out:
#   ID WEIGHT HEIGHT  AGE GENDER
# 0  1  144.5    5.9   33      M
# 1  2  167.2    5.4   45      M
# 2  3  124.1    5.2   23      F
# 3  4  144.5    5.9   33      M
# 4  5  133.2    5.7   54      F

# %%
df_persona.tail()
# Out:
#   ID WEIGHT HEIGHT  AGE GENDER
# 2  3  124.1    5.2   23      F
# 3  4  144.5    5.9   33      M
# 4  5  133.2    5.7   54      F
# 5  3  124.1    5.2   23      F
# 6  5  129.2    5.3   42      M

# %%
df_persona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      7 non-null      object
#  1   WEIGHT  7 non-null      object
#  2   HEIGHT  7 non-null      object
#  3   AGE     7 non-null      int64
#  4   GENDER  7 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 408.0+ bytes
